# %%
import numpy as np
data= np.load('data.npy')
target=np.load('target.npy')


print('karunakar')
# Out:
# karunakar

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(200,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(50,activation='relu'))
model.add(Dense(2,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])


print('karunakar')
# Out:
# karunakar

# %%
from sklearn.model_selection import train_test_split
train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

print('karunakar')
# Out:
# karunakar

# %%
checkpoint=ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(train_data,train_target,epochs=10,callbacks=[checkpoint],validation_split=0.2)

print('karunakar')
# Out:
# Epoch 1/10
# 86/86 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9945INFO:tensorflow:Assets written to: model-001.model\assets
# 86/86 [==============================] - 232s 3s/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.4731 - val_accuracy: 0.9184
# Epoch 2/10
# 86/86 [==============================] - 211s 2s/step - loss: 0.0108 - accuracy: 0.9974 - val_loss: 0.4817 - val_accuracy: 0.9067
# Epoch 3/10
# 86/86 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9974INFO:tensorflow:Assets written to: model-003.model\assets
# 86/86 [==============================] - 225s 3s/step - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.4166 - val_accuracy: 0.9213
# Epoch 4/10
# 86/86 [==============================] - 296s 3s/step - loss: 0.0088 - accuracy: 0.9982 - val_loss: 0.4320 - val_accuracy: 0.9227
# Epoch 5/10
# 86/86 [==============================] - 259s 3s/step - loss: 0.0188 - accuracy: 0.9945 - val_loss: 0.4594 - val_accuracy: 0.9125
# Epoch 6/10
# 86/86 [==============================] - 282s 3s/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.4638 - val_accuracy: 0.9096
# Epoch 7/10
# 86/86 [==============================] - 292s 3s/step - loss: 0.0075 - accuracy: 0.9971 - val_loss: 0.5994 - val_accuracy: 0.9067
# Epoch 8/10
# 86/86 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9938INFO:tensorflow:Assets written to: model-008.model\assets
# 86/86 [==============================] - 284s 3s/step - loss: 0.0218 - accuracy: 0.9938 - val_loss: 0.3975 - val_accuracy: 0.9140
# Epoch 9/10
# 86/86 [==============================] - 226s 3s/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.4927 - val_accuracy: 0.9198
# Epoch 10/10
# 86/86 [==============================] - 223s 3s/step - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.4127 - val_accuracy: 0.9198
# karunakar

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'],'r',label='training loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

print('karunakar')
# Out:
# karunakar

# %%
plt.plot(history.history['accuracy'],'r',label='training accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

print('karunakar')
# Out:
# karunakar
